# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'Untitled.ipynb']

# %%
import pandas as pd
import xlrd
df1 = pd.read_csv("supermarkets.csv")
df2 = pd.read_json("supermarkets.json")
df3 = pd.read_excel("supermarkets.xlsx")
df4 = pd.read_csv("supermarkets-commas.txt")
df5 = pd.read_csv("supermarkets-semi-colons.txt", sep=";")
df6 = pd.read_csv("http://pythonhow.com/supermarkets.csv")

# %%
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df1.loc[4,"City":"Name"]
# Out:
# City       San Francisco
# State         California
# Country              USA
# Name             Sanchez
# Name: 4, dtype: object

# %%
df1.iloc[0:3,1:4]
# Out:
#           Address           City             State
# 0    3666 21st St  San Francisco          CA 94114
# 1  735 Dolores St  San Francisco          CA 94119
# 2     332 Hill St  San Francisco  California 94114

# %%
df1.ix? #depricated

# %%
df1 = df1.drop("City", 1)
df1
# Out:
#    ID          Address             State Country         Name  Employees
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20

# %%
df1["Continenet"] = df1.shape[0]*["America"]

# %%
df1
# Out:
#    ID          Address             State Country         Name  Employees  \
# 0   1     3666 21st St          CA 94114     USA      Madeira          8
# 1   2   735 Dolores St          CA 94119     USA  Bready Shop         15
# 2   3      332 Hill St  California 94114     USA  Super River         25
# 3   4     3995 23rd St          CA 94114     USA   Ben's Shop         10
# 4   5  1056 Sanchez St        California     USA      Sanchez         12
# 5   6  551 Alvarado St          CA 94114     USA   Richvalley         20
#
#   Continenet
# 0    America
# 1    America
# 2    America
# 3    America
# 4    America
# 5    America

# %%
df6
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dn  = pd.merge(left=df4,right=df5,on="ID")

# %%
dn
# Out:
#    ID        Address_x         City_x           State_x Country_x  \
# 0   1     3666 21st St  San Francisco          CA 94114       USA
# 1   2   735 Dolores St  San Francisco          CA 94119       USA
# 2   3      332 Hill St  San Francisco  California 94114       USA
# 3   4     3995 23rd St  San Francisco          CA 94114       USA
# 4   5  1056 Sanchez St  San Francisco        California       USA
# 5   6  551 Alvarado St  San Francisco          CA 94114       USA
#
#         Name_x  Employees_x        Address_y         City_y           State_y  \
# 0      Madeira            8     3666 21st St  San Francisco          CA 94114
# 1  Bready Shop           15   735 Dolores St  San Francisco          CA 94119
# 2  Super River           25      332 Hill St  San Francisco  California 94114
# 3   Ben's Shop           10     3995 23rd St  San Francisco          CA 94114
# 4      Sanchez           12  1056 Sanchez St  San Francisco        California
# ...

# %%
from geopy.geocoders import ArcGIS
nom = ArcGIS()

# %%
nom.geocode("3666 21st St, San Francisco, CA 94114")
# Out:
# Location(3666 21st St, San Francisco, California, 94114, (37.75644449321933, -122.42935314363206, 0.0))

# %%
df1["Address"] = df1["Address"]+", "+df1["State"]+", "+df1["Country"]
df1
# Out:
#    ID                                            Address             State  \
# 0   1         3666 21st St, CA 94114, USA, CA 94114, USA          CA 94114
# 1   2       735 Dolores St, CA 94119, USA, CA 94119, USA          CA 94119
# 2   3  332 Hill St, California 94114, USA, California...  California 94114
# 3   4         3995 23rd St, CA 94114, USA, CA 94114, USA          CA 94114
# 4   5  1056 Sanchez St, California, USA, California, USA        California
# 5   6      551 Alvarado St, CA 94114, USA, CA 94114, USA          CA 94114
#
#   Country         Name  Employees Continenet
# 0     USA      Madeira          8    America
# 1     USA  Bready Shop         15    America
# 2     USA  Super River         25    America
# 3     USA   Ben's Shop         10    America
# 4     USA      Sanchez         12    America
# 5     USA   Richvalley         20    America

# %%
df1["location"] = df1["Address"].apply(nom.geocode)
df1
# Out:
#    ID                                            Address             State  \
# 0   1         3666 21st St, CA 94114, USA, CA 94114, USA          CA 94114
# 1   2       735 Dolores St, CA 94119, USA, CA 94119, USA          CA 94119
# 2   3  332 Hill St, California 94114, USA, California...  California 94114
# 3   4         3995 23rd St, CA 94114, USA, CA 94114, USA          CA 94114
# 4   5  1056 Sanchez St, California, USA, California, USA        California
# 5   6      551 Alvarado St, CA 94114, USA, CA 94114, USA          CA 94114
#
#   Country         Name  Employees Continenet  \
# 0     USA      Madeira          8    America
# 1     USA  Bready Shop         15    America
# 2     USA  Super River         25    America
# 3     USA   Ben's Shop         10    America
# 4     USA      Sanchez         12    America
# 5     USA   Richvalley         20    America
#
#                                             location
# 0  (3666 21st St, San Francisco, California, 9411...
# ...

# %%
df1["Latitude"] = df1["location"].apply(lambda x: x.latitude)

# %%
df1["Longitude"] = df1["location"].apply(lambda x: x.longitude)
